# %% [markdown]
# <a href="https://colab.research.google.com/github/Dua-Sharif/Machine-Learning/blob/main/Lab01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
dataset = pd.read_csv('/content/Insurance.csv')
dataset.head()
# Out:
#    NumOfClaims  Payments
# 0          108     392.5
# 1           19      46.2
# 2           13      15.7
# 3          124     422.2
# 4           40     119.4

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   NumOfClaims  26 non-null     int64
#  1   Payments     26 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 548.0 bytes

# %%
dataset.shape
# Out:
# (26, 2)

# %%
dataset.columns
# Out:
# Index(['NumOfClaims', 'Payments'], dtype='object')

# %%
dataset.describe
# Out:
# <bound method NDFrame.describe of     NumOfClaims  Payments
# 0           108     392.5
# 1            19      46.2
# 2            13      15.7
# 3           124     422.2
# 4            40     119.4
# 5            57     170.9
# 6            23      56.9
# 7            14      77.5
# 8            45     214.0
# 9            10      65.3
# 10            5      20.9
# 11           48     248.1
# 12           11      23.5
# 13           23      39.6
# 14            7      48.8
# 15            2       6.6
# 16           24     134.9
# 17            6      50.9
# 18            3       4.4
# 19           23     113.0
# 20            6      14.8
# 21            9      48.7
# 22            9      52.1
# 23            3      13.2
# 24           29     103.9
# 25            7      77.5>

# %%
X = dataset.iloc[:,:-1]
y = dataset.iloc[:,-1]

# %%
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size = 0.4, random_state = 0)

# %%
X_train.shape
# Out:
# (15, 1)

# %%
model= LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(f"Intercept (b): {model.intercept_}")
print(f"Slope (a): {model.coef_}")
# Out:
# Intercept (b): 10.002781511630289
# Slope (a): [3.42596498]

# %%
plt.scatter(X_train,y_train,color='blue')
plt.plot(X_train,model.predict(X_train),color='black')
plt.title("Simple Linear Regression on Training Data")
plt.xlabel("No. of Claims")
plt.ylabel("Payment")
plt.show()

# %%
y_pred = model.predict(X_test)

# %%
plt.scatter(X_test,y_test,color='blue')
plt.plot(X_test,model.predict(X_test),color='black')
plt.title("Simple Linear Regression on Testing Data")
plt.xlabel("No. of Claims")
plt.ylabel("Payment")
plt.show()

# %%
print(f"Mean Absolute Error: {metrics.mean_absolute_error(y_test,y_pred)}")
print(f"Mean Squared Error: {metrics.mean_squared_error(y_test,y_pred)}")
print(f"Root Mean Squared Error: {np.sqrt(metrics.mean_squared_error(y_test,y_pred))}")
# Out:
# Mean Absolute Error: 31.000703976795876
# Mean Squared Error: 1291.202117474736
# Root Mean Squared Error: 35.93330095433394
